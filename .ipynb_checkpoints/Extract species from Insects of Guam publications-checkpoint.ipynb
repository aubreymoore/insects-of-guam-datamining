# %% [markdown]
# Note: Run with Python 3 kernel.

# %% [markdown]
# # Utility Functions (called by other functions)

# %%
def combine_images_vertically(img1, img2):
    """
    Glues 2 images together with img2 below img1.
    Returns the new compound image.
    """
    
    import numpy as np
    
    h1, w1 = img1.shape
    h2, w2 = img2.shape

    # Create an array big enough to hold img2 below img1.
    img = np.zeros(((h1 + h2), max(w1, w2)), np.float32)

    # Paste img1 at y=0, x=0
    img[0:img1.shape[0], 0:img1.shape[1]] = img1

    # Paste img2 at y=h1, x=0
    img[h1:h1+img2.shape[0],0:img2.shape[1]] = img2    
    return img

# %%
def scrape_bishop_bulletins_page(bulletin):
    """
    Scrapes data from the Bishop Museum pubs online web page. 
    Bulletin is b172 for Insects of Guam I and b189 for Insects of Guam II.
    A directory named b172 or b189 is created and populated with a CSV file, named b189.csv, containing
    titles, stubs, authors, and urls for pdfs.
    If the bulletin directory already exists, this function does nothing.
    """
    import requests
    import os
    import pandas as pd
    from bs4 import BeautifulSoup
    from urllib.parse import urljoin
    from slugify import slugify
    
    if bulletin not in ['b172', 'b189']:
        print("bulletin not in ['b172', 'b189']")
        return

    bulletins_url = 'http://hbs.bishopmuseum.org/pubs-online/bpbm-bulletins.html'
    result = requests.get(bulletins_url)
    soup = BeautifulSoup(result.content, features = "lxml")

    pdf_list = []
    links = soup.find_all('a')
    for link in links:
        if bulletin in link.get('href'):
            text = link.previous_sibling.previous_sibling.previous_sibling
            parts = text.split(', by ')
            if len(parts) == 2:
                title = parts[0].strip()
                slug = slugify(title)
                authors = parts[1].replace('[','').strip()          
                url = link.get('href')
                url = urljoin(bulletins_url, url)
                pdf_list.append({'title':title, 'slug':slug, 'authors':authors, 'url':url})
    
    df_pdf_list = pd.DataFrame(pdf_list)
    os.mkdir(bulletin)
    outfile = '{}/{}.csv'.format(bulletin, bulletin)
    df_pdf_list.to_csv(outfile, index=False)
    
    return

## Usage example:
#scrape_bishop_bulletins_page('b172')

# %% [raw]
# import docker
#
# client = docker.from_env()
#
# for container in client.containers.list():
#     container.stop()
#
# data = container = client.containers.run('cvat', detach=True)
# print(data)
# file_json = data.get_archive('testdump.xml')
# stream, stat = file_json
# file_obj = BytesIO()
# for i in stream:
#     file_obj.write(i)
# file_obj.seek(0)
# tar = tarfile.open(mode='r', fileobj=file_obj)
# text = tar.extractfile('out.json')
# q = text.read()
# print(q)

# %% [markdown]
# # Main Functions

# %%
def create_file_structure(bulletin):
    """
    bulletin is 'b172' for Insects of Guam I and 'b189' for Insects of Guam II.
    Depends on scrape_bishop_bulletins_page
    Creates a data file structure in this format:
    
    b172
        anthribidae-of-guam
            anthribidae-of-guam.pdf
            anthribidae-of-guam-0.jpg
            anthribidae-of-guam-1.jpg
            ...
        formicidae-of-guam
            formicidae-of-guam.pdf
            formicidae-of-guam-0.jpg
            formicidae-of-guam-1.jpg
            ...
            
    Each directory contains a PDF file and a JPG image for each page in the PDF.
    
    """
    import requests
    import os
    import subprocess
    import pandas as pd
    
    if bulletin not in ['b172', 'b189']:
        print("bulletin not in ['b172', 'b189']")
        return
    
    if not os.path.exists(bulletin):
        print('{} directory does not exist.'.format(bulletin))
        print('Scraping Bishop Museum Bulletins web page.')
        scrape_bishop_bulletins_page(bulletin)
    
    pdf_list = pd.read_csv('{}/{}.csv'.format(bulletin, bulletin)).to_dict('records')
    
    os.chdir('b172'); print(os.getcwd())
    for d in pdf_list:
        slug = d['slug']
        if os.path.exists(slug):
            print('{} directory already exists.'.format(slug))
            continue

        # Create a new directory and move into it
        url = d['url']
        os.mkdir(slug); os.chdir(slug); print(os.getcwd())

        # Download PDF
        filename = '{}.pdf'.format(slug)
        r = requests.get(url)
        open(filename, 'wb').write(r.content)

        # Create a JPG image for each page in PDF using the Linux convert command
        jpg = filename.replace('pdf', 'jpg')
        subprocess.call(['convert', '-density', '200x200', filename, jpg])

        # Move up one directory
        os.chdir('..'); print(os.getcwd())
    os.chdir('..'); print(os.getcwd())
    return

#create_file_structure('b172')

# %%
def make_bounding_box_table(bulletin, section):
    """
    
    """
    from bs4 import BeautifulSoup
    import pandas as pd

    xml_file_path = '{}/{}/{}.xml'.format(bulletin, section, section)
    f = open(xml_file_path, 'r')
    contents = f.read()
    soup = BeautifulSoup(contents, features = "lxml")

    bb_list = []
    n = -1
    for image in soup.find_all('image'):
        for box in image.find_all('box'):
            n += 1
            species_name = box.text.replace('\n','')
            bb_list.append({
                'species_name':species_name, 
                'page_image':image['name'],
                'bb_image': '{}-{}.jpg'.format(species_name.replace(' ', '-'), n),
                'xtl':int(float(box['xtl'])),
                'ytl':int(float(box['ytl'])),
                'xbr':int(float(box['xbr'])),
                'ybr':int(float(box['ybr']))
            })
    df_bb_list = pd.DataFrame(bb_list)
    outfile = '{}/{}/bounding_boxes.csv'.format(bulletin, section)
    df_bb_list.to_csv(outfile, index=False)
    return

#make_bounding_box_table('b172', 'barkbeetles-of-guam')

# %%
def extract_bounding_box_images(bulletin, section):
    """
    
    """
    import cv2
    import os
    
    bb_list_csv_path = '{}/{}/bounding_boxes.csv'.format(bulletin, section)  
    df_bb_list = pd.read_csv(bb_list_csv_path)

    mydir = '{}/{}/bounding_box_images'.format(bulletin, section)
    if not os.path.exists(mydir):
        os.mkdir(mydir)

    # Extract bounding box images
    for i, r in df_bb_list.iterrows():
        page_image_path = '{}/{}/{}'.format(bulletin, section, r.page_image)
        im = cv2.imread(page_image_path)
        roi = im[r.ytl:r.ybr, r.xtl:r.xbr]
        roi_filename = '{}/{}'.format(mydir, r.bb_image)
        print(roi_filename)    
        cv2.imwrite(roi_filename, roi)
    return

#extract_bounding_box_images('b172', 'barkbeetles-of-guam')

# %%
def merge_bounding_box_images(bulletin, section):
    """
    
    """
    import pandas as pd
    import pandasql as ps
    import cv2
    import numpy as np

    
    bb_list_csv_path = '{}/{}/bounding_boxes.csv'.format(bulletin, section)  
    df_bb_list = pd.read_csv(bb_list_csv_path)

    mydir = '{}/{}/bounding_box_images'.format(bulletin, section)

    merged_image_dir = '{}/{}/merged_images'.format(bulletin, section)
    if not os.path.exists(merged_image_dir):
        os.mkdir(merged_image_dir)

    sql = '''select species_name 
    from df_bb_list 
    group by species_name 
    order by species_name'''
    species_names = ps.sqldf(sql)
    
    print('species_names: {}'.format(species_names))
    
    for species_name in species_names.values:
        species_name = species_name[0]
        print(species_name)
        sql = '''select bb_image 
        from df_bb_list 
        where species_name="{}" 
        order by bb_image'''.format(species_name)
        df = ps.sqldf(sql)
        print(df)
        print()

        rowcount = df.shape[0]
        print('rowcount: {}'.format(rowcount))
        if rowcount > 2:
            print('More than 2 images to be merged. Not implemented. Continuiing.')
            continue
        if rowcount == 1:
            f = '{}/{}'.format(mydir, df.bb_image[0])
            print('f: {}'.format(f))
            img = cv2.imread(f, 0)
            #cv2.imshow('caca',img)
        if rowcount == 2:
            f = '{}/{}'.format(mydir, df.bb_image[0])
            print('f: {}'.format(f))
            img1 = cv2.imread(f, 0)
            print(img1)
            
            f = '{}/{}'.format(mydir, df.bb_image[1])
            print('f: {}'.format(f))
            img2 = cv2.imread(f, 0)  
            #print('img1 shape: {}'.format(img1.shp))
            #print('img2 shape: {}'.format(img2.shp))
            img = combine_images_vertically(img1, img2)
        f = '{}/{}.jpg'.format(merged_image_dir, species_name)
        cv2.imwrite(f, img)
    return
    
#merge_bounding_box_images('b172', 'barkbeetles-of-guam')

# %%
def make_mturk_data_csv(bulletin, section):
    """
    """
    import glob
    import pytesseract

    try:
        from PIL import Image
    except ImportError:
        import Image

    prefix = 'https://github.com/aubreymoore/insects-of-guam-datamining/raw/master'

    imagefiles = glob.glob('{}/{}/merged_images/*.jpg'.format(bulletin, section))
    outfile = '{}/{}/mturk_data.csv'.format(bulletin, section)

    with open(outfile, 'w+') as out:
        out.write('image_url,text\n')
        for imagefile in imagefiles:
            image_url = '{}/{}'.format(prefix, imagefile)

            # Perform optical character recognition on the image
            #text = pytesseract.image_to_string(Image.open(fn)).encode('utf-8')    

            print('performing optical character recognition on {}'.format(imagefile))
            text = pytesseract.image_to_string(Image.open(imagefile))

            # Remove double quotes and replace line feeds with <br>
            text = text.replace('\n\n', '\n')
            text = text.replace('"', '').replace('\n', '<br>')

            # Separate collection records into individual lines of text
            text = text.replace(';', '<br>')

            # write record
            out.write('{},"{}"\n'.format(image_url, text))  
            
    return

#make_mturk_data_csv('b172', 'barkbeetles-of-guam')

# %% [markdown]
# # MAIN

# %%
bulletin = 'b172'
create_file_structure(bulletin)
# Out:
# /home/aubrey/insects-of-guam-test/b172
# dragonflies-of-guam directory already exists.
# thrips-of-guam directory already exists.
# cercopidae-of-guam directory already exists.
# membracidae-of-guam directory already exists.
# psyllidae-from-guam directory already exists.
# aphidae-and-aleurodidae-of-guam directory already exists.
# neuropteroid-insects-from-guam directory already exists.
# butterflies-of-guam directory already exists.
# sphingidae-of-guam directory already exists.
# staphylinidae-of-guam directory already exists.
# rhipiceridae-of-guam directory already exists.
# ciidae-of-guam directory already exists.
# elaterid-and-eucnemid-beetles-of-guam directory already exists.
# coleoptera-heteromera-from-guam directory already exists.
# new-longicorn-beetles-from-guam-cerambycidae directory already exists.
# anthribidae-of-guam directory already exists.
# curculionidae-of-guam directory already exists.
# barkbeetles-of-guam directory already exists.
# miscellaneous-families-of-guam-coleoptera directory already exists.
# stylopidae-of-guam directory already exists.
# formicidae-of-guam directory already exists.
# wasps-of-guam directory already exists.
# bees-of-guam directory already exists.
# halictine-bees-from-rota-island directory already exists.
# tipulidae-of-guam directory already exists.
# culicidae-of-guam directory already exists.
# trypetidae-otitidae-helomyzidae-and-clusiidae-of-guam-diptera directory already exists.
# /home/aubrey/insects-of-guam-test

# %% [markdown]
# At this point the directory structure should look something like this:
#
#     b172
#         anthribidae-of-guam
#             anthribidae-of-guam.pdf
#             anthribidae-of-guam-0.jpg
#             anthribidae-of-guam-1.jpg
#             ...
#         formicidae-of-guam
#             formicidae-of-guam.pdf
#             formicidae-of-guam-0.jpg
#             formicidae-of-guam-1.jpg
#             ...
#
# The PDF contains the whole section.
# There is JPG file for each page in the section.
#
# The next step is to use CVAT to record coordinates of bounding boxes which determine the position of species
# sections in the JPGs.  The resulting XML file can be downloaded into the section directory.
#
# Then, rerun this notebook, commit changes to the git repo, and push to github.

# %%
import pandas as pd
import os
import cv2

f = '{}/{}.csv'.format(bulletin, bulletin)
df = pd.read_csv(f)
for section in df.slug.values:
    print(section)
    bb_xml_path = '{}/{}/{}.xml'.format(bulletin, section, section)
    bb_xml_path_exists = os.path.exists(bb_xml_path)
    print('bb_xml_path_exists: {}'.format(bb_xml_path_exists))
    bb_csv_path = '{}/{}/bounding_boxes.csv'.format(bulletin, section)
    bb_csv_path_exists = os.path.exists(bb_csv_path)
    print('bb_csv_path_exists: {}'.format(bb_csv_path_exists))
    
    if bb_xml_path_exists and not bb_csv_path_exists:
        print('Making bb table for {}'.format(section))
        make_bounding_box_table(bulletin, section)
        
        print('Extracting bounding box images.')
        extract_bounding_box_images(bulletin, section)
        
        print('Merging bounding box images.')
        merge_bounding_box_images(bulletin, section)
        
        print('Making mturk data csv.')
        make_mturk_data_csv(bulletin, section)
    print()
# Out:
# dragonflies-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# thrips-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# cercopidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# membracidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# psyllidae-from-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# aphidae-and-aleurodidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# neuropteroid-insects-from-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# butterflies-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# sphingidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# staphylinidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# rhipiceridae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# ciidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: False
# Making bb table for ciidae-of-guam
# Extracting bounding box images.
# b172/ciidae-of-guam/bounding_box_images/Cis-quadridentatus-0.jpg
# b172/ciidae-of-guam/bounding_box_images/Cis-guamae-1.jpg
# b172/ciidae-of-guam/bounding_box_images/Cis-agariconae-2.jpg
# b172/ciidae-of-guam/bounding_box_images/Cis-agariconae-3.jpg
# b172/ciidae-of-guam/bounding_box_images/Ceracis-palaceps-4.jpg
# b172/ciidae-of-guam/bounding_box_images/Ceracis-palaceps-5.jpg
# Merging bounding box images.
# species_names:          species_name
# 0    Ceracis palaceps
# 1      Cis agariconae
# 2          Cis guamae
# 3  Cis quadridentatus
# Ceracis palaceps
#                  bb_image
# 0  Ceracis-palaceps-4.jpg
# 1  Ceracis-palaceps-5.jpg
#
# rowcount: 2
# f: b172/ciidae-of-guam/bounding_box_images/Ceracis-palaceps-4.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/ciidae-of-guam/bounding_box_images/Ceracis-palaceps-5.jpg
# Cis agariconae
#                bb_image
# 0  Cis-agariconae-2.jpg
# 1  Cis-agariconae-3.jpg
#
# rowcount: 2
# f: b172/ciidae-of-guam/bounding_box_images/Cis-agariconae-2.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/ciidae-of-guam/bounding_box_images/Cis-agariconae-3.jpg
# Cis guamae
#            bb_image
# 0  Cis-guamae-1.jpg
#
# rowcount: 1
# f: b172/ciidae-of-guam/bounding_box_images/Cis-guamae-1.jpg
# Cis quadridentatus
#                    bb_image
# 0  Cis-quadridentatus-0.jpg
#
# rowcount: 1
# f: b172/ciidae-of-guam/bounding_box_images/Cis-quadridentatus-0.jpg
# Making mturk data csv.
# performing optical character recognition on b172/ciidae-of-guam/merged_images/Cis agariconae.jpg
# performing optical character recognition on b172/ciidae-of-guam/merged_images/Ceracis palaceps.jpg
# performing optical character recognition on b172/ciidae-of-guam/merged_images/Cis guamae.jpg
# performing optical character recognition on b172/ciidae-of-guam/merged_images/Cis quadridentatus.jpg
#
# elaterid-and-eucnemid-beetles-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: False
# Making bb table for elaterid-and-eucnemid-beetles-of-guam
# Extracting bounding box images.
# b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Agrypnus-bifoveatus-0.jpg
# b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Lacon-modestus-1.jpg
# b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Simodactylus-cinnamomeus-2.jpg
# b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Simodactylus-3.jpg
# b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Melanoxanthus-melanocephalus-4.jpg
# b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Melanoxanthus-palustris-5.jpg
# b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Melanoxanthus-guamensis-6.jpg
# b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Melanoxanthus-palustris-7.jpg
# b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Melanoxanthus-unsingeri-8.jpg
# b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Fornax-coxalis-9.jpg
# Merging bounding box images.
# species_names:                    species_name
# 0           Agrypnus bifoveatus
# 1                Fornax coxalis
# 2                Lacon modestus
# 3       Melanoxanthus guamensis
# 4  Melanoxanthus melanocephalus
# 5       Melanoxanthus palustris
# 6       Melanoxanthus unsingeri
# 7                  Simodactylus
# 8      Simodactylus cinnamomeus
# Agrypnus bifoveatus
#                     bb_image
# 0  Agrypnus-bifoveatus-0.jpg
#
# rowcount: 1
# f: b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Agrypnus-bifoveatus-0.jpg
# Fornax coxalis
#                bb_image
# 0  Fornax-coxalis-9.jpg
#
# rowcount: 1
# f: b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Fornax-coxalis-9.jpg
# Lacon modestus
#                bb_image
# 0  Lacon-modestus-1.jpg
#
# rowcount: 1
# f: b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Lacon-modestus-1.jpg
# Melanoxanthus guamensis
#                         bb_image
# 0  Melanoxanthus-guamensis-6.jpg
#
# rowcount: 1
# f: b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Melanoxanthus-guamensis-6.jpg
# Melanoxanthus melanocephalus
#                              bb_image
# 0  Melanoxanthus-melanocephalus-4.jpg
#
# rowcount: 1
# f: b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Melanoxanthus-melanocephalus-4.jpg
# Melanoxanthus palustris
#                         bb_image
# 0  Melanoxanthus-palustris-5.jpg
# 1  Melanoxanthus-palustris-7.jpg
#
# rowcount: 2
# f: b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Melanoxanthus-palustris-5.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Melanoxanthus-palustris-7.jpg
# Melanoxanthus unsingeri
#                         bb_image
# 0  Melanoxanthus-unsingeri-8.jpg
#
# rowcount: 1
# f: b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Melanoxanthus-unsingeri-8.jpg
# Simodactylus
#              bb_image
# 0  Simodactylus-3.jpg
#
# rowcount: 1
# f: b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Simodactylus-3.jpg
# Simodactylus cinnamomeus
#                          bb_image
# 0  Simodactylus-cinnamomeus-2.jpg
#
# rowcount: 1
# f: b172/elaterid-and-eucnemid-beetles-of-guam/bounding_box_images/Simodactylus-cinnamomeus-2.jpg
# Making mturk data csv.
# performing optical character recognition on b172/elaterid-and-eucnemid-beetles-of-guam/merged_images/Melanoxanthus melanocephalus.jpg
# performing optical character recognition on b172/elaterid-and-eucnemid-beetles-of-guam/merged_images/Fornax coxalis.jpg
# performing optical character recognition on b172/elaterid-and-eucnemid-beetles-of-guam/merged_images/Lacon modestus.jpg
# performing optical character recognition on b172/elaterid-and-eucnemid-beetles-of-guam/merged_images/Agrypnus bifoveatus.jpg
# performing optical character recognition on b172/elaterid-and-eucnemid-beetles-of-guam/merged_images/Simodactylus.jpg
# performing optical character recognition on b172/elaterid-and-eucnemid-beetles-of-guam/merged_images/Melanoxanthus unsingeri.jpg
# performing optical character recognition on b172/elaterid-and-eucnemid-beetles-of-guam/merged_images/Melanoxanthus guamensis.jpg
# performing optical character recognition on b172/elaterid-and-eucnemid-beetles-of-guam/merged_images/Simodactylus cinnamomeus.jpg
# performing optical character recognition on b172/elaterid-and-eucnemid-beetles-of-guam/merged_images/Melanoxanthus palustris.jpg
#
# coleoptera-heteromera-from-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# new-longicorn-beetles-from-guam-cerambycidae
# bb_xml_path_exists: True
# bb_csv_path_exists: False
# Making bb table for new-longicorn-beetles-from-guam-cerambycidae
# Extracting bounding box images.
# b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Iphrobrium-guamensis-0.jpg
# b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Nonymoides-swezeyi-1.jpg
# b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Nonymoides-swezeyi-2.jpg
# b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Nonymoides-minimus-3.jpg
# b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Ceresium-4.jpg
# b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Ceresium-guttaticolle-5.jpg
# b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Sybra-carolina-6.jpg
# b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Sybra-7.jpg
# b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Ropica-8.jpg
# Merging bounding box images.
# species_names:             species_name
# 0               Ceresium
# 1  Ceresium guttaticolle
# 2   Iphrobrium guamensis
# 3     Nonymoides minimus
# 4     Nonymoides swezeyi
# 5                 Ropica
# 6                  Sybra
# 7         Sybra carolina
# Ceresium
#          bb_image
# 0  Ceresium-4.jpg
#
# rowcount: 1
# f: b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Ceresium-4.jpg
# Ceresium guttaticolle
#                       bb_image
# 0  Ceresium-guttaticolle-5.jpg
#
# rowcount: 1
# f: b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Ceresium-guttaticolle-5.jpg
# Iphrobrium guamensis
#                      bb_image
# 0  Iphrobrium-guamensis-0.jpg
#
# rowcount: 1
# f: b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Iphrobrium-guamensis-0.jpg
# Nonymoides minimus
#                    bb_image
# 0  Nonymoides-minimus-3.jpg
#
# rowcount: 1
# f: b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Nonymoides-minimus-3.jpg
# Nonymoides swezeyi
#                    bb_image
# 0  Nonymoides-swezeyi-1.jpg
# 1  Nonymoides-swezeyi-2.jpg
#
# rowcount: 2
# f: b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Nonymoides-swezeyi-1.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Nonymoides-swezeyi-2.jpg
# Ropica
#        bb_image
# 0  Ropica-8.jpg
#
# rowcount: 1
# f: b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Ropica-8.jpg
# Sybra
#       bb_image
# 0  Sybra-7.jpg
#
# rowcount: 1
# f: b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Sybra-7.jpg
# Sybra carolina
#                bb_image
# 0  Sybra-carolina-6.jpg
#
# rowcount: 1
# f: b172/new-longicorn-beetles-from-guam-cerambycidae/bounding_box_images/Sybra-carolina-6.jpg
# Making mturk data csv.
# performing optical character recognition on b172/new-longicorn-beetles-from-guam-cerambycidae/merged_images/Nonymoides minimus.jpg
# performing optical character recognition on b172/new-longicorn-beetles-from-guam-cerambycidae/merged_images/Ceresium.jpg
# performing optical character recognition on b172/new-longicorn-beetles-from-guam-cerambycidae/merged_images/Iphrobrium guamensis.jpg
# performing optical character recognition on b172/new-longicorn-beetles-from-guam-cerambycidae/merged_images/Ceresium guttaticolle.jpg
# performing optical character recognition on b172/new-longicorn-beetles-from-guam-cerambycidae/merged_images/Sybra.jpg
# performing optical character recognition on b172/new-longicorn-beetles-from-guam-cerambycidae/merged_images/Ropica.jpg
# performing optical character recognition on b172/new-longicorn-beetles-from-guam-cerambycidae/merged_images/Sybra carolina.jpg
# performing optical character recognition on b172/new-longicorn-beetles-from-guam-cerambycidae/merged_images/Nonymoides swezeyi.jpg
#
# anthribidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# curculionidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: False
# Making bb table for curculionidae-of-guam
# Extracting bounding box images.
# b172/curculionidae-of-guam/bounding_box_images/Trigonops-inusitata-0.jpg
# b172/curculionidae-of-guam/bounding_box_images/Trigonops-inusitata-1.jpg
# b172/curculionidae-of-guam/bounding_box_images/Trigonops-inaequalis-2.jpg
# b172/curculionidae-of-guam/bounding_box_images/Trigonops-inaequalis-3.jpg
# b172/curculionidae-of-guam/bounding_box_images/Trigonops-subfasciata-4.jpg
# b172/curculionidae-of-guam/bounding_box_images/Trigonops-hirsuta-5.jpg
# b172/curculionidae-of-guam/bounding_box_images/Trigonops-hirsuta-6.jpg
# b172/curculionidae-of-guam/bounding_box_images/Trigonops-impura-7.jpg
# b172/curculionidae-of-guam/bounding_box_images/Trigonops-incrinita-8.jpg
# b172/curculionidae-of-guam/bounding_box_images/Trigonops-impura-9.jpg
# b172/curculionidae-of-guam/bounding_box_images/Trigonops-convexa-10.jpg
# b172/curculionidae-of-guam/bounding_box_images/Trigonops-incrinita-11.jpg
# b172/curculionidae-of-guam/bounding_box_images/Trigonops-convexa-12.jpg
# b172/curculionidae-of-guam/bounding_box_images/Trigonops-vulgaris-13.jpg
# b172/curculionidae-of-guam/bounding_box_images/Trigonops-vulgaris-14.jpg
# b172/curculionidae-of-guam/bounding_box_images/Cylas-formicarius-15.jpg
# b172/curculionidae-of-guam/bounding_box_images/Usingerius-maculatus-16.jpg
# b172/curculionidae-of-guam/bounding_box_images/Usingerius-maculatus-17.jpg
# b172/curculionidae-of-guam/bounding_box_images/Amblycnemus-dentipes-18.jpg
# b172/curculionidae-of-guam/bounding_box_images/Athesapeuta-ulvae-19.jpg
# b172/curculionidae-of-guam/bounding_box_images/Athesapeuta-ulvae-20.jpg
# b172/curculionidae-of-guam/bounding_box_images/Fergusoniella-21.jpg
# b172/curculionidae-of-guam/bounding_box_images/Swezeyella-muscosa-22.jpg
# b172/curculionidae-of-guam/bounding_box_images/Deretiosus-ficae-23.jpg
# b172/curculionidae-of-guam/bounding_box_images/Camptorhinus-dorsalis-24.jpg
# b172/curculionidae-of-guam/bounding_box_images/Oreda-maculata-25.jpg
# b172/curculionidae-of-guam/bounding_box_images/Menectetorus-tutuilae-26.jpg
# b172/curculionidae-of-guam/bounding_box_images/Menectetorus-vitiensis-27.jpg
# b172/curculionidae-of-guam/bounding_box_images/Menectetorus-setulosus-28.jpg
# b172/curculionidae-of-guam/bounding_box_images/Neoampagia-imitator-29.jpg
# b172/curculionidae-of-guam/bounding_box_images/Anaballus-amplicollis--30.jpg
# b172/curculionidae-of-guam/bounding_box_images/Euscepes-postfasciatus-31.jpg
# b172/curculionidae-of-guam/bounding_box_images/Acalles-samoanus-32.jpg
# b172/curculionidae-of-guam/bounding_box_images/Daealus-tuberosus-33.jpg
# b172/curculionidae-of-guam/bounding_box_images/Daealus-tuberosus-34.jpg
# b172/curculionidae-of-guam/bounding_box_images/Daealus-tibialis-35.jpg
# b172/curculionidae-of-guam/bounding_box_images/Microcryptorhynchus-guamae-36.jpg
# b172/curculionidae-of-guam/bounding_box_images/Microcryptorhynchus-premnae-37.jpg
# b172/curculionidae-of-guam/bounding_box_images/Microcryptorhynchus-spinifer-38.jpg
# b172/curculionidae-of-guam/bounding_box_images/Microcryptorhynchus-basipennis-39.jpg
# b172/curculionidae-of-guam/bounding_box_images/Cylindrotrypetes-suffusus-40.jpg
# b172/curculionidae-of-guam/bounding_box_images/Choerorrhinodes-constricticeps-41.jpg
# b172/curculionidae-of-guam/bounding_box_images/Choerorrhinodes-marshalli-42.jpg
# b172/curculionidae-of-guam/bounding_box_images/Choerorrhinodes-flavisetosus-43.jpg
# b172/curculionidae-of-guam/bounding_box_images/Choerorrhinodes-flavisetosus-44.jpg
# b172/curculionidae-of-guam/bounding_box_images/Stenotrupis-tenuis-45.jpg
# b172/curculionidae-of-guam/bounding_box_images/Tytthoxydema-exilis-46.jpg
# b172/curculionidae-of-guam/bounding_box_images/Rhinanisodes-planicollis-47.jpg
# b172/curculionidae-of-guam/bounding_box_images/Himatinum-bisetosum-48.jpg
# b172/curculionidae-of-guam/bounding_box_images/Rhinanisodes-planicollis-49.jpg
# b172/curculionidae-of-guam/bounding_box_images/Himatinum-bisetosum-50.jpg
# b172/curculionidae-of-guam/bounding_box_images/Dryotribodes-obscurus--51.jpg
# b172/curculionidae-of-guam/bounding_box_images/Dryotribodes-obscurus--52.jpg
# b172/curculionidae-of-guam/bounding_box_images/Dryotribodes-angularis-53.jpg
# b172/curculionidae-of-guam/bounding_box_images/Dryotribodes-angularis-54.jpg
# b172/curculionidae-of-guam/bounding_box_images/Dryotribodes-denticulatus-55.jpg
# b172/curculionidae-of-guam/bounding_box_images/Dryotribodes-denticulatus-56.jpg
# b172/curculionidae-of-guam/bounding_box_images/Oxydema-fusiforme-57.jpg
# b172/curculionidae-of-guam/bounding_box_images/Oxydema-longulum-58.jpg
# b172/curculionidae-of-guam/bounding_box_images/Aphanocorynes-humeralis-59.jpg
# b172/curculionidae-of-guam/bounding_box_images/Eutornus-nigriceps-60.jpg
# b172/curculionidae-of-guam/bounding_box_images/Eutornus-nigriceps-61.jpg
# b172/curculionidae-of-guam/bounding_box_images/Macrancylus-niger-62.jpg
# b172/curculionidae-of-guam/bounding_box_images/Phloeophagosoma-sulcirostre-63.jpg
# b172/curculionidae-of-guam/bounding_box_images/Macrancylus-niger-64.jpg
# b172/curculionidae-of-guam/bounding_box_images/Viticis-guamae-65.jpg
# b172/curculionidae-of-guam/bounding_box_images/Viticis-guamae-66.jpg
# b172/curculionidae-of-guam/bounding_box_images/Rhabdocnemis-obscura-67.jpg
# b172/curculionidae-of-guam/bounding_box_images/Cosmo-polites-sordidus-68.jpg
# b172/curculionidae-of-guam/bounding_box_images/Polytus-mellerborgi-69.jpg
# b172/curculionidae-of-guam/bounding_box_images/Calandra-oryzae-70.jpg
# b172/curculionidae-of-guam/bounding_box_images/Diocalandra-frumenti-71.jpg
# b172/curculionidae-of-guam/bounding_box_images/Diocalandra-frumenti-72.jpg
# b172/curculionidae-of-guam/bounding_box_images/Trigonops-insularis-73.jpg
# Merging bounding box images.
# species_names:                       species_name
# 0                 Acalles samoanus
# 1             Amblycnemus dentipes
# 2           Anaballus amplicollis
# 3          Aphanocorynes humeralis
# 4                Athesapeuta ulvae
# 5                  Calandra oryzae
# 6            Camptorhinus dorsalis
# 7   Choerorrhinodes constricticeps
# 8     Choerorrhinodes flavisetosus
# 9        Choerorrhinodes marshalli
# 10          Cosmo polites sordidus
# 11               Cylas formicarius
# 12       Cylindrotrypetes suffusus
# 13                Daealus tibialis
# 14               Daealus tuberosus
# 15                Deretiosus ficae
# 16            Diocalandra frumenti
# 17          Dryotribodes angularis
# 18       Dryotribodes denticulatus
# 19          Dryotribodes obscurus
# 20          Euscepes postfasciatus
# 21              Eutornus nigriceps
# 22                   Fergusoniella
# 23             Himatinum bisetosum
# 24               Macrancylus niger
# 25          Menectetorus setulosus
# 26           Menectetorus tutuilae
# 27          Menectetorus vitiensis
# 28  Microcryptorhynchus basipennis
# 29      Microcryptorhynchus guamae
# 30     Microcryptorhynchus premnae
# 31    Microcryptorhynchus spinifer
# 32             Neoampagia imitator
# 33                  Oreda maculata
# 34               Oxydema fusiforme
# 35                Oxydema longulum
# 36     Phloeophagosoma sulcirostre
# 37             Polytus mellerborgi
# 38            Rhabdocnemis obscura
# 39        Rhinanisodes planicollis
# 40              Stenotrupis tenuis
# 41              Swezeyella muscosa
# 42               Trigonops convexa
# 43               Trigonops hirsuta
# 44                Trigonops impura
# 45            Trigonops inaequalis
# 46             Trigonops incrinita
# 47             Trigonops insularis
# 48             Trigonops inusitata
# 49           Trigonops subfasciata
# 50              Trigonops vulgaris
# 51             Tytthoxydema exilis
# 52            Usingerius maculatus
# 53                  Viticis guamae
# Acalles samoanus
#                   bb_image
# 0  Acalles-samoanus-32.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Acalles-samoanus-32.jpg
# Amblycnemus dentipes
#                       bb_image
# 0  Amblycnemus-dentipes-18.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Amblycnemus-dentipes-18.jpg
# Anaballus amplicollis
#                         bb_image
# 0  Anaballus-amplicollis--30.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Anaballus-amplicollis--30.jpg
# Aphanocorynes humeralis
#                          bb_image
# 0  Aphanocorynes-humeralis-59.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Aphanocorynes-humeralis-59.jpg
# Athesapeuta ulvae
#                    bb_image
# 0  Athesapeuta-ulvae-19.jpg
# 1  Athesapeuta-ulvae-20.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Athesapeuta-ulvae-19.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Athesapeuta-ulvae-20.jpg
# Calandra oryzae
#                  bb_image
# 0  Calandra-oryzae-70.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Calandra-oryzae-70.jpg
# Camptorhinus dorsalis
#                        bb_image
# 0  Camptorhinus-dorsalis-24.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Camptorhinus-dorsalis-24.jpg
# Choerorrhinodes constricticeps
#                                 bb_image
# 0  Choerorrhinodes-constricticeps-41.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Choerorrhinodes-constricticeps-41.jpg
# Choerorrhinodes flavisetosus
#                               bb_image
# 0  Choerorrhinodes-flavisetosus-43.jpg
# 1  Choerorrhinodes-flavisetosus-44.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Choerorrhinodes-flavisetosus-43.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Choerorrhinodes-flavisetosus-44.jpg
# Choerorrhinodes marshalli
#                            bb_image
# 0  Choerorrhinodes-marshalli-42.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Choerorrhinodes-marshalli-42.jpg
# Cosmo polites sordidus
#                         bb_image
# 0  Cosmo-polites-sordidus-68.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Cosmo-polites-sordidus-68.jpg
# Cylas formicarius
#                    bb_image
# 0  Cylas-formicarius-15.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Cylas-formicarius-15.jpg
# Cylindrotrypetes suffusus
#                            bb_image
# 0  Cylindrotrypetes-suffusus-40.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Cylindrotrypetes-suffusus-40.jpg
# Daealus tibialis
#                   bb_image
# 0  Daealus-tibialis-35.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Daealus-tibialis-35.jpg
# Daealus tuberosus
#                    bb_image
# 0  Daealus-tuberosus-33.jpg
# 1  Daealus-tuberosus-34.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Daealus-tuberosus-33.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Daealus-tuberosus-34.jpg
# Deretiosus ficae
#                   bb_image
# 0  Deretiosus-ficae-23.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Deretiosus-ficae-23.jpg
# Diocalandra frumenti
#                       bb_image
# 0  Diocalandra-frumenti-71.jpg
# 1  Diocalandra-frumenti-72.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Diocalandra-frumenti-71.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Diocalandra-frumenti-72.jpg
# Dryotribodes angularis
#                         bb_image
# 0  Dryotribodes-angularis-53.jpg
# 1  Dryotribodes-angularis-54.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Dryotribodes-angularis-53.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Dryotribodes-angularis-54.jpg
# Dryotribodes denticulatus
#                            bb_image
# 0  Dryotribodes-denticulatus-55.jpg
# 1  Dryotribodes-denticulatus-56.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Dryotribodes-denticulatus-55.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Dryotribodes-denticulatus-56.jpg
# Dryotribodes obscurus
#                         bb_image
# 0  Dryotribodes-obscurus--51.jpg
# 1  Dryotribodes-obscurus--52.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Dryotribodes-obscurus--51.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Dryotribodes-obscurus--52.jpg
# Euscepes postfasciatus
#                         bb_image
# 0  Euscepes-postfasciatus-31.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Euscepes-postfasciatus-31.jpg
# Eutornus nigriceps
#                     bb_image
# 0  Eutornus-nigriceps-60.jpg
# 1  Eutornus-nigriceps-61.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Eutornus-nigriceps-60.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Eutornus-nigriceps-61.jpg
# Fergusoniella
#                bb_image
# 0  Fergusoniella-21.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Fergusoniella-21.jpg
# Himatinum bisetosum
#                      bb_image
# 0  Himatinum-bisetosum-48.jpg
# 1  Himatinum-bisetosum-50.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Himatinum-bisetosum-48.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Himatinum-bisetosum-50.jpg
# Macrancylus niger
#                    bb_image
# 0  Macrancylus-niger-62.jpg
# 1  Macrancylus-niger-64.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Macrancylus-niger-62.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Macrancylus-niger-64.jpg
# Menectetorus setulosus
#                         bb_image
# 0  Menectetorus-setulosus-28.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Menectetorus-setulosus-28.jpg
# Menectetorus tutuilae
#                        bb_image
# 0  Menectetorus-tutuilae-26.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Menectetorus-tutuilae-26.jpg
# Menectetorus vitiensis
#                         bb_image
# 0  Menectetorus-vitiensis-27.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Menectetorus-vitiensis-27.jpg
# Microcryptorhynchus basipennis
#                                 bb_image
# 0  Microcryptorhynchus-basipennis-39.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Microcryptorhynchus-basipennis-39.jpg
# Microcryptorhynchus guamae
#                             bb_image
# 0  Microcryptorhynchus-guamae-36.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Microcryptorhynchus-guamae-36.jpg
# Microcryptorhynchus premnae
#                              bb_image
# 0  Microcryptorhynchus-premnae-37.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Microcryptorhynchus-premnae-37.jpg
# Microcryptorhynchus spinifer
#                               bb_image
# 0  Microcryptorhynchus-spinifer-38.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Microcryptorhynchus-spinifer-38.jpg
# Neoampagia imitator
#                      bb_image
# 0  Neoampagia-imitator-29.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Neoampagia-imitator-29.jpg
# Oreda maculata
#                 bb_image
# 0  Oreda-maculata-25.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Oreda-maculata-25.jpg
# Oxydema fusiforme
#                    bb_image
# 0  Oxydema-fusiforme-57.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Oxydema-fusiforme-57.jpg
# Oxydema longulum
#                   bb_image
# 0  Oxydema-longulum-58.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Oxydema-longulum-58.jpg
# Phloeophagosoma sulcirostre
#                              bb_image
# 0  Phloeophagosoma-sulcirostre-63.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Phloeophagosoma-sulcirostre-63.jpg
# Polytus mellerborgi
#                      bb_image
# 0  Polytus-mellerborgi-69.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Polytus-mellerborgi-69.jpg
# Rhabdocnemis obscura
#                       bb_image
# 0  Rhabdocnemis-obscura-67.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Rhabdocnemis-obscura-67.jpg
# Rhinanisodes planicollis
#                           bb_image
# 0  Rhinanisodes-planicollis-47.jpg
# 1  Rhinanisodes-planicollis-49.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Rhinanisodes-planicollis-47.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Rhinanisodes-planicollis-49.jpg
# Stenotrupis tenuis
#                     bb_image
# 0  Stenotrupis-tenuis-45.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Stenotrupis-tenuis-45.jpg
# Swezeyella muscosa
#                     bb_image
# 0  Swezeyella-muscosa-22.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Swezeyella-muscosa-22.jpg
# Trigonops convexa
#                    bb_image
# 0  Trigonops-convexa-10.jpg
# 1  Trigonops-convexa-12.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Trigonops-convexa-10.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Trigonops-convexa-12.jpg
# Trigonops hirsuta
#                   bb_image
# 0  Trigonops-hirsuta-5.jpg
# 1  Trigonops-hirsuta-6.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Trigonops-hirsuta-5.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Trigonops-hirsuta-6.jpg
# Trigonops impura
#                  bb_image
# 0  Trigonops-impura-7.jpg
# 1  Trigonops-impura-9.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Trigonops-impura-7.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Trigonops-impura-9.jpg
# Trigonops inaequalis
#                      bb_image
# 0  Trigonops-inaequalis-2.jpg
# 1  Trigonops-inaequalis-3.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Trigonops-inaequalis-2.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Trigonops-inaequalis-3.jpg
# Trigonops incrinita
#                      bb_image
# 0  Trigonops-incrinita-11.jpg
# 1   Trigonops-incrinita-8.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Trigonops-incrinita-11.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Trigonops-incrinita-8.jpg
# Trigonops insularis
#                      bb_image
# 0  Trigonops-insularis-73.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Trigonops-insularis-73.jpg
# Trigonops inusitata
#                     bb_image
# 0  Trigonops-inusitata-0.jpg
# 1  Trigonops-inusitata-1.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Trigonops-inusitata-0.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Trigonops-inusitata-1.jpg
# Trigonops subfasciata
#                       bb_image
# 0  Trigonops-subfasciata-4.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Trigonops-subfasciata-4.jpg
# Trigonops vulgaris
#                     bb_image
# 0  Trigonops-vulgaris-13.jpg
# 1  Trigonops-vulgaris-14.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Trigonops-vulgaris-13.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Trigonops-vulgaris-14.jpg
# Tytthoxydema exilis
#                      bb_image
# 0  Tytthoxydema-exilis-46.jpg
#
# rowcount: 1
# f: b172/curculionidae-of-guam/bounding_box_images/Tytthoxydema-exilis-46.jpg
# Usingerius maculatus
#                       bb_image
# 0  Usingerius-maculatus-16.jpg
# 1  Usingerius-maculatus-17.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Usingerius-maculatus-16.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Usingerius-maculatus-17.jpg
# Viticis guamae
#                 bb_image
# 0  Viticis-guamae-65.jpg
# 1  Viticis-guamae-66.jpg
#
# rowcount: 2
# f: b172/curculionidae-of-guam/bounding_box_images/Viticis-guamae-65.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/curculionidae-of-guam/bounding_box_images/Viticis-guamae-66.jpg
# Making mturk data csv.
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Tytthoxydema exilis.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Fergusoniella.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Macrancylus niger.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Dryotribodes obscurus .jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Acalles samoanus.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Eutornus nigriceps.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Microcryptorhynchus basipennis.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Choerorrhinodes flavisetosus.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Oreda maculata.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Polytus mellerborgi.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Trigonops convexa.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Swezeyella muscosa.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Menectetorus setulosus.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Microcryptorhynchus spinifer.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Oxydema fusiforme.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Calandra oryzae.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Daealus tuberosus.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Phloeophagosoma sulcirostre.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Trigonops subfasciata.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Deretiosus ficae.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Cylindrotrypetes suffusus.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Microcryptorhynchus guamae.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Trigonops vulgaris.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Rhabdocnemis obscura.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Dryotribodes denticulatus.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Dryotribodes angularis.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Trigonops impura.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Microcryptorhynchus premnae.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Trigonops inaequalis.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Cylas formicarius.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Viticis guamae.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Menectetorus tutuilae.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Cosmo polites sordidus.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Trigonops inusitata.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Daealus tibialis.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Neoampagia imitator.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Trigonops hirsuta.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Euscepes postfasciatus.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Stenotrupis tenuis.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Choerorrhinodes constricticeps.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Camptorhinus dorsalis.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Anaballus amplicollis .jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Aphanocorynes humeralis.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Diocalandra frumenti.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Rhinanisodes planicollis.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Himatinum bisetosum.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Usingerius maculatus.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Trigonops incrinita.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Menectetorus vitiensis.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Athesapeuta ulvae.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Amblycnemus dentipes.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Oxydema longulum.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Choerorrhinodes marshalli.jpg
# performing optical character recognition on b172/curculionidae-of-guam/merged_images/Trigonops insularis.jpg
#
# barkbeetles-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# miscellaneous-families-of-guam-coleoptera
# bb_xml_path_exists: False
# bb_csv_path_exists: False
#
# stylopidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: False
# Making bb table for stylopidae-of-guam
# Extracting bounding box images.
# b172/stylopidae-of-guam/bounding_box_images/Elenchoides-perkinsi-0.jpg
# Merging bounding box images.
# species_names:            species_name
# 0  Elenchoides perkinsi
# Elenchoides perkinsi
#                      bb_image
# 0  Elenchoides-perkinsi-0.jpg
#
# rowcount: 1
# f: b172/stylopidae-of-guam/bounding_box_images/Elenchoides-perkinsi-0.jpg
# Making mturk data csv.
# performing optical character recognition on b172/stylopidae-of-guam/merged_images/Elenchoides perkinsi.jpg
#
# formicidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: False
# Making bb table for formicidae-of-guam
# Extracting bounding box images.
# b172/formicidae-of-guam/bounding_box_images/Cerapachys-silvestrii-0.jpg
# b172/formicidae-of-guam/bounding_box_images/Ponera-punctatissima-1.jpg
# b172/formicidae-of-guam/bounding_box_images/Odontomachus-haematoda-2.jpg
# b172/formicidae-of-guam/bounding_box_images/Cremastogaster-biroi-3.jpg
# b172/formicidae-of-guam/bounding_box_images/Cerapachys-silvestrii-4.jpg
# b172/formicidae-of-guam/bounding_box_images/Strumigenys-godeffroyi-5.jpg
# b172/formicidae-of-guam/bounding_box_images/Monomorium-pharaonis-6.jpg
# b172/formicidae-of-guam/bounding_box_images/Monomorium-minutum-7.jpg
# b172/formicidae-of-guam/bounding_box_images/Monomorium-floricola-8.jpg
# b172/formicidae-of-guam/bounding_box_images/Monomorium-destructor-9.jpg
# b172/formicidae-of-guam/bounding_box_images/Strumigenys-godeffroyi-10.jpg
# b172/formicidae-of-guam/bounding_box_images/Monomorium-minutum-11.jpg
# b172/formicidae-of-guam/bounding_box_images/Pheidole-javana-12.jpg
# b172/formicidae-of-guam/bounding_box_images/Solenopsis--13.jpg
# b172/formicidae-of-guam/bounding_box_images/Solenopsis-geminata--14.jpg
# b172/formicidae-of-guam/bounding_box_images/Cardiocondyla-wroughtoni-15.jpg
# b172/formicidae-of-guam/bounding_box_images/Pheidole-umboata-16.jpg
# b172/formicidae-of-guam/bounding_box_images/Pheidole--17.jpg
# b172/formicidae-of-guam/bounding_box_images/Pheidole--18.jpg
# b172/formicidae-of-guam/bounding_box_images/Tetramorium-guineense-19.jpg
# b172/formicidae-of-guam/bounding_box_images/Triglyphotrix-striatidens-20.jpg
# b172/formicidae-of-guam/bounding_box_images/Pheidole-umbonata-21.jpg
# b172/formicidae-of-guam/bounding_box_images/Tapinoma-indicum-22.jpg
# b172/formicidae-of-guam/bounding_box_images/Triglyphotrix-striatidens-23.jpg
# b172/formicidae-of-guam/bounding_box_images/Vollenhovia-oblonga-24.jpg
# b172/formicidae-of-guam/bounding_box_images/Tapinoma-melanocephalum-25.jpg
# b172/formicidae-of-guam/bounding_box_images/ANoplolepis-longipes-26.jpg
# b172/formicidae-of-guam/bounding_box_images/Technomyrmex-albipes-27.jpg
# b172/formicidae-of-guam/bounding_box_images/Tapinoma-indicum-28.jpg
# b172/formicidae-of-guam/bounding_box_images/Nylanderia-minutula-atomus-fullawayi-29.jpg
# b172/formicidae-of-guam/bounding_box_images/Camponotus-irritans-chloroticus-30.jpg
# b172/formicidae-of-guam/bounding_box_images/Nylanderia-bourbonica-31.jpg
# b172/formicidae-of-guam/bounding_box_images/Nylanderia-minutula-atomus-fullawayi-32.jpg
# b172/formicidae-of-guam/bounding_box_images/Paratrechina-longicornis-33.jpg
# b172/formicidae-of-guam/bounding_box_images/Camponotus-irritans-chloroticus-34.jpg
# b172/formicidae-of-guam/bounding_box_images/Camponotus-reticulatus-fullawayi-35.jpg
# Merging bounding box images.
# species_names:                             species_name
# 0                   ANoplolepis longipes
# 1        Camponotus irritans chloroticus
# 2       Camponotus reticulatus fullawayi
# 3               Cardiocondyla wroughtoni
# 4                  Cerapachys silvestrii
# 5                   Cremastogaster biroi
# 6                  Monomorium destructor
# 7                   Monomorium floricola
# 8                     Monomorium minutum
# 9                   Monomorium pharaonis
# 10                 Nylanderia bourbonica
# 11  Nylanderia minutula atomus fullawayi
# 12                Odontomachus haematoda
# 13              Paratrechina longicornis
# 14                             Pheidole
# 15                       Pheidole javana
# 16                      Pheidole umboata
# 17                     Pheidole umbonata
# 18                  Ponera punctatissima
# 19                           Solenopsis
# 20                  Solenopsis geminata
# 21                Strumigenys godeffroyi
# 22                      Tapinoma indicum
# 23               Tapinoma melanocephalum
# 24                  Technomyrmex albipes
# 25                 Tetramorium guineense
# 26             Triglyphotrix striatidens
# 27                   Vollenhovia oblonga
# ANoplolepis longipes
#                       bb_image
# 0  ANoplolepis-longipes-26.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/ANoplolepis-longipes-26.jpg
# Camponotus irritans chloroticus
#                                  bb_image
# 0  Camponotus-irritans-chloroticus-30.jpg
# 1  Camponotus-irritans-chloroticus-34.jpg
#
# rowcount: 2
# f: b172/formicidae-of-guam/bounding_box_images/Camponotus-irritans-chloroticus-30.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/formicidae-of-guam/bounding_box_images/Camponotus-irritans-chloroticus-34.jpg
# Camponotus reticulatus fullawayi
#                                   bb_image
# 0  Camponotus-reticulatus-fullawayi-35.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Camponotus-reticulatus-fullawayi-35.jpg
# Cardiocondyla wroughtoni
#                           bb_image
# 0  Cardiocondyla-wroughtoni-15.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Cardiocondyla-wroughtoni-15.jpg
# Cerapachys silvestrii
#                       bb_image
# 0  Cerapachys-silvestrii-0.jpg
# 1  Cerapachys-silvestrii-4.jpg
#
# rowcount: 2
# f: b172/formicidae-of-guam/bounding_box_images/Cerapachys-silvestrii-0.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/formicidae-of-guam/bounding_box_images/Cerapachys-silvestrii-4.jpg
# Cremastogaster biroi
#                      bb_image
# 0  Cremastogaster-biroi-3.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Cremastogaster-biroi-3.jpg
# Monomorium destructor
#                       bb_image
# 0  Monomorium-destructor-9.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Monomorium-destructor-9.jpg
# Monomorium floricola
#                      bb_image
# 0  Monomorium-floricola-8.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Monomorium-floricola-8.jpg
# Monomorium minutum
#                     bb_image
# 0  Monomorium-minutum-11.jpg
# 1   Monomorium-minutum-7.jpg
#
# rowcount: 2
# f: b172/formicidae-of-guam/bounding_box_images/Monomorium-minutum-11.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/formicidae-of-guam/bounding_box_images/Monomorium-minutum-7.jpg
# Monomorium pharaonis
#                      bb_image
# 0  Monomorium-pharaonis-6.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Monomorium-pharaonis-6.jpg
# Nylanderia bourbonica
#                        bb_image
# 0  Nylanderia-bourbonica-31.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Nylanderia-bourbonica-31.jpg
# Nylanderia minutula atomus fullawayi
#                                       bb_image
# 0  Nylanderia-minutula-atomus-fullawayi-29.jpg
# 1  Nylanderia-minutula-atomus-fullawayi-32.jpg
#
# rowcount: 2
# f: b172/formicidae-of-guam/bounding_box_images/Nylanderia-minutula-atomus-fullawayi-29.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/formicidae-of-guam/bounding_box_images/Nylanderia-minutula-atomus-fullawayi-32.jpg
# Odontomachus haematoda
#                        bb_image
# 0  Odontomachus-haematoda-2.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Odontomachus-haematoda-2.jpg
# Paratrechina longicornis
#                           bb_image
# 0  Paratrechina-longicornis-33.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Paratrechina-longicornis-33.jpg
# Pheidole
#            bb_image
# 0  Pheidole--17.jpg
# 1  Pheidole--18.jpg
#
# rowcount: 2
# f: b172/formicidae-of-guam/bounding_box_images/Pheidole--17.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/formicidae-of-guam/bounding_box_images/Pheidole--18.jpg
# Pheidole javana
#                  bb_image
# 0  Pheidole-javana-12.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Pheidole-javana-12.jpg
# Pheidole umboata
#                   bb_image
# 0  Pheidole-umboata-16.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Pheidole-umboata-16.jpg
# Pheidole umbonata
#                    bb_image
# 0  Pheidole-umbonata-21.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Pheidole-umbonata-21.jpg
# Ponera punctatissima
#                      bb_image
# 0  Ponera-punctatissima-1.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Ponera-punctatissima-1.jpg
# Solenopsis
#              bb_image
# 0  Solenopsis--13.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Solenopsis--13.jpg
# Solenopsis geminata
#                       bb_image
# 0  Solenopsis-geminata--14.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Solenopsis-geminata--14.jpg
# Strumigenys godeffroyi
#                         bb_image
# 0  Strumigenys-godeffroyi-10.jpg
# 1   Strumigenys-godeffroyi-5.jpg
#
# rowcount: 2
# f: b172/formicidae-of-guam/bounding_box_images/Strumigenys-godeffroyi-10.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/formicidae-of-guam/bounding_box_images/Strumigenys-godeffroyi-5.jpg
# Tapinoma indicum
#                   bb_image
# 0  Tapinoma-indicum-22.jpg
# 1  Tapinoma-indicum-28.jpg
#
# rowcount: 2
# f: b172/formicidae-of-guam/bounding_box_images/Tapinoma-indicum-22.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/formicidae-of-guam/bounding_box_images/Tapinoma-indicum-28.jpg
# Tapinoma melanocephalum
#                          bb_image
# 0  Tapinoma-melanocephalum-25.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Tapinoma-melanocephalum-25.jpg
# Technomyrmex albipes
#                       bb_image
# 0  Technomyrmex-albipes-27.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Technomyrmex-albipes-27.jpg
# Tetramorium guineense
#                        bb_image
# 0  Tetramorium-guineense-19.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Tetramorium-guineense-19.jpg
# Triglyphotrix striatidens
#                            bb_image
# 0  Triglyphotrix-striatidens-20.jpg
# 1  Triglyphotrix-striatidens-23.jpg
#
# rowcount: 2
# f: b172/formicidae-of-guam/bounding_box_images/Triglyphotrix-striatidens-20.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/formicidae-of-guam/bounding_box_images/Triglyphotrix-striatidens-23.jpg
# Vollenhovia oblonga
#                      bb_image
# 0  Vollenhovia-oblonga-24.jpg
#
# rowcount: 1
# f: b172/formicidae-of-guam/bounding_box_images/Vollenhovia-oblonga-24.jpg
# Making mturk data csv.
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Monomorium pharaonis.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Tapinoma indicum.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Solenopsis geminata .jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Strumigenys godeffroyi.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Odontomachus haematoda.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Pheidole umboata.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Cerapachys silvestrii.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Vollenhovia oblonga.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Solenopsis .jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Pheidole .jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Monomorium floricola.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Cremastogaster biroi.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Camponotus irritans chloroticus.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Nylanderia bourbonica.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Ponera punctatissima.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Triglyphotrix striatidens.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Tetramorium guineense.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Nylanderia minutula atomus fullawayi.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Monomorium destructor.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/ANoplolepis longipes.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Camponotus reticulatus fullawayi.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Paratrechina longicornis.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Pheidole javana.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Pheidole umbonata.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Technomyrmex albipes.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Monomorium minutum.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Cardiocondyla wroughtoni.jpg
# performing optical character recognition on b172/formicidae-of-guam/merged_images/Tapinoma melanocephalum.jpg
#
# wasps-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# bees-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# halictine-bees-from-rota-island
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# tipulidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# culicidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# trypetidae-otitidae-helomyzidae-and-clusiidae-of-guam-diptera
# bb_xml_path_exists: True
# bb_csv_path_exists: True

# %% [markdown]
# # END
