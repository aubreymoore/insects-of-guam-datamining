# %% [markdown]
# Note: Run with Python 3 kernel.

# %% [markdown]
# # Utility Functions (called by other functions)

# %%
def combine_images_vertically(img1, img2):
    """
    Glues 2 images together with img2 below img1.
    Returns the new compound image.
    """
    
    import numpy as np
    
    h1, w1 = img1.shape
    h2, w2 = img2.shape

    # Create an array big enough to hold img2 below img1.
    img = np.zeros(((h1 + h2), max(w1, w2)), np.float32)

    # Paste img1 at y=0, x=0
    img[0:img1.shape[0], 0:img1.shape[1]] = img1

    # Paste img2 at y=h1, x=0
    img[h1:h1+img2.shape[0],0:img2.shape[1]] = img2    
    return img

# %%
def scrape_bishop_bulletins_page(bulletin):
    """
    Scrapes data from the Bishop Museum pubs online web page. 
    Bulletin is b172 for Insects of Guam I and b189 for Insects of Guam II.
    A directory named b172 or b189 is created and populated with a CSV file, named b189.csv, containing
    titles, stubs, authors, and urls for pdfs.
    If the bulletin directory already exists, this function does nothing.
    """
    import requests
    import os
    import pandas as pd
    from bs4 import BeautifulSoup
    from urllib.parse import urljoin
    from slugify import slugify
    
    if bulletin not in ['b172', 'b189']:
        print("bulletin not in ['b172', 'b189']")
        return

    bulletins_url = 'http://hbs.bishopmuseum.org/pubs-online/bpbm-bulletins.html'
    result = requests.get(bulletins_url)
    soup = BeautifulSoup(result.content, features = "lxml")

    pdf_list = []
    links = soup.find_all('a')
    for link in links:
        if bulletin in link.get('href'):
            text = link.previous_sibling.previous_sibling.previous_sibling
            parts = text.split(', by ')
            if len(parts) == 2:
                title = parts[0].strip()
                slug = slugify(title)
                authors = parts[1].replace('[','').strip()          
                url = link.get('href')
                url = urljoin(bulletins_url, url)
                pdf_list.append({'title':title, 'slug':slug, 'authors':authors, 'url':url})
    
    df_pdf_list = pd.DataFrame(pdf_list)
    os.mkdir(bulletin)
    outfile = '{}/{}.csv'.format(bulletin, bulletin)
    df_pdf_list.to_csv(outfile, index=False)
    
    return

## Usage example:
#scrape_bishop_bulletins_page('b172')

# %% [raw]
# import docker
#
# client = docker.from_env()
#
# for container in client.containers.list():
#     container.stop()
#
# data = container = client.containers.run('cvat', detach=True)
# print(data)
# file_json = data.get_archive('testdump.xml')
# stream, stat = file_json
# file_obj = BytesIO()
# for i in stream:
#     file_obj.write(i)
# file_obj.seek(0)
# tar = tarfile.open(mode='r', fileobj=file_obj)
# text = tar.extractfile('out.json')
# q = text.read()
# print(q)

# %% [markdown]
# # Main Functions

# %%
def create_file_structure(bulletin):
    """
    bulletin is 'b172' for Insects of Guam I and 'b189' for Insects of Guam II.
    Depends on scrape_bishop_bulletins_page
    Creates a data file structure in this format:
    
    b172
        anthribidae-of-guam
            anthribidae-of-guam.pdf
            anthribidae-of-guam-0.jpg
            anthribidae-of-guam-1.jpg
            ...
        formicidae-of-guam
            formicidae-of-guam.pdf
            formicidae-of-guam-0.jpg
            formicidae-of-guam-1.jpg
            ...
            
    Each directory contains a PDF file and a JPG image for each page in the PDF.
    
    """
    import requests
    import os
    import subprocess
    import pandas as pd
    
    if bulletin not in ['b172', 'b189']:
        print("bulletin not in ['b172', 'b189']")
        return
    
    if not os.path.exists(bulletin):
        print('{} directory does not exist.'.format(bulletin))
        print('Scraping Bishop Museum Bulletins web page.')
        scrape_bishop_bulletins_page(bulletin)
    
    pdf_list = pd.read_csv('{}/{}.csv'.format(bulletin, bulletin)).to_dict('records')
    
    os.chdir('b172'); print(os.getcwd())
    for d in pdf_list:
        slug = d['slug']
        if os.path.exists(slug):
            print('{} directory already exists.'.format(slug))
            continue

        # Create a new directory and move into it
        url = d['url']
        os.mkdir(slug); os.chdir(slug); print(os.getcwd())

        # Download PDF
        filename = '{}.pdf'.format(slug)
        r = requests.get(url)
        open(filename, 'wb').write(r.content)

        # Create a JPG image for each page in PDF using the Linux convert command
        jpg = filename.replace('pdf', 'jpg')
        subprocess.call(['convert', '-density', '200x200', filename, jpg])

        # Move up one directory
        os.chdir('..'); print(os.getcwd())
    os.chdir('..'); print(os.getcwd())
    return

#create_file_structure('b172')

# %%
def make_bounding_box_table(bulletin, section):
    """
    
    """
    from bs4 import BeautifulSoup
    import pandas as pd

    xml_file_path = '{}/{}/{}.xml'.format(bulletin, section, section)
    f = open(xml_file_path, 'r')
    contents = f.read()
    soup = BeautifulSoup(contents, features = "lxml")

    bb_list = []
    n = -1
    for image in soup.find_all('image'):
        for box in image.find_all('box'):
            n += 1
            species_name = box.text.replace('\n','')
            bb_list.append({
                'species_name':species_name, 
                'page_image':image['name'],
                'bb_image': '{}-{}.jpg'.format(species_name.replace(' ', '-'), n),
                'xtl':int(float(box['xtl'])),
                'ytl':int(float(box['ytl'])),
                'xbr':int(float(box['xbr'])),
                'ybr':int(float(box['ybr']))
            })
    df_bb_list = pd.DataFrame(bb_list)
    outfile = '{}/{}/bounding_boxes.csv'.format(bulletin, section)
    df_bb_list.to_csv(outfile, index=False)
    return

#make_bounding_box_table('b172', 'barkbeetles-of-guam')

# %%
def extract_bounding_box_images(bulletin, section):
    """
    
    """
    import cv2
    import os
    
    bb_list_csv_path = '{}/{}/bounding_boxes.csv'.format(bulletin, section)  
    df_bb_list = pd.read_csv(bb_list_csv_path)

    mydir = '{}/{}/bounding_box_images'.format(bulletin, section)
    if not os.path.exists(mydir):
        os.mkdir(mydir)

    # Extract bounding box images
    for i, r in df_bb_list.iterrows():
        page_image_path = '{}/{}/{}'.format(bulletin, section, r.page_image)
        im = cv2.imread(page_image_path)
        roi = im[r.ytl:r.ybr, r.xtl:r.xbr]
        roi_filename = '{}/{}'.format(mydir, r.bb_image)
        print(roi_filename)    
        cv2.imwrite(roi_filename, roi)
    return

#extract_bounding_box_images('b172', 'barkbeetles-of-guam')

# %%
def merge_bounding_box_images(bulletin, section):
    """
    
    """
    import pandas as pd
    import pandasql as ps
    import cv2
    import numpy as np

    
    bb_list_csv_path = '{}/{}/bounding_boxes.csv'.format(bulletin, section)  
    df_bb_list = pd.read_csv(bb_list_csv_path)

    mydir = '{}/{}/bounding_box_images'.format(bulletin, section)

    merged_image_dir = '{}/{}/merged_images'.format(bulletin, section)
    if not os.path.exists(merged_image_dir):
        os.mkdir(merged_image_dir)

    sql = '''select species_name 
    from df_bb_list 
    group by species_name 
    order by species_name'''
    species_names = ps.sqldf(sql)
    
    print('species_names: {}'.format(species_names))
    
    for species_name in species_names.values:
        species_name = species_name[0]
        print(species_name)
        sql = '''select bb_image 
        from df_bb_list 
        where species_name="{}" 
        order by bb_image'''.format(species_name)
        df = ps.sqldf(sql)
        print(df)
        print()

        rowcount = df.shape[0]
        print('rowcount: {}'.format(rowcount))
        if rowcount > 2:
            print('More than 2 images to be merged. Not implemented. Continuiing.')
            continue
        if rowcount == 1:
            f = '{}/{}'.format(mydir, df.bb_image[0])
            print('f: {}'.format(f))
            img = cv2.imread(f, 0)
            #cv2.imshow('caca',img)
        if rowcount == 2:
            f = '{}/{}'.format(mydir, df.bb_image[0])
            print('f: {}'.format(f))
            img1 = cv2.imread(f, 0)
            print(img1)
            
            f = '{}/{}'.format(mydir, df.bb_image[1])
            print('f: {}'.format(f))
            img2 = cv2.imread(f, 0)  
            #print('img1 shape: {}'.format(img1.shp))
            #print('img2 shape: {}'.format(img2.shp))
            img = combine_images_vertically(img1, img2)
        f = '{}/{}.jpg'.format(merged_image_dir, species_name)
        cv2.imwrite(f, img)
    return
    
#merge_bounding_box_images('b172', 'barkbeetles-of-guam')

# %%
def make_mturk_data_csv(bulletin, section):
    """
    """
    import glob
    import pytesseract

    try:
        from PIL import Image
    except ImportError:
        import Image

    prefix = 'https://github.com/aubreymoore/insects-of-guam-datamining/raw/master'

    imagefiles = glob.glob('{}/{}/merged_images/*.jpg'.format(bulletin, section))
    outfile = '{}/{}/mturk_data.csv'.format(bulletin, section)

    with open(outfile, 'w+') as out:
        out.write('image_url,text\n')
        for imagefile in imagefiles:
            image_url = '{}/{}'.format(prefix, imagefile)

            # Perform optical character recognition on the image
            #text = pytesseract.image_to_string(Image.open(fn)).encode('utf-8')    

            print('performing optical character recognition on {}'.format(imagefile))
            text = pytesseract.image_to_string(Image.open(imagefile))

            # Remove double quotes and replace line feeds with <br>
            text = text.replace('\n\n', '\n')
            text = text.replace('"', '').replace('\n', '<br>')

            # Separate collection records into individual lines of text
            text = text.replace(';', '<br>')

            # write record
            out.write('{},"{}"\n'.format(image_url, text))  
            
    return

#make_mturk_data_csv('b172', 'barkbeetles-of-guam')

# %% [markdown]
# # MAIN

# %%
bulletin = 'b172'
create_file_structure(bulletin)
# Out:
# /home/aubrey/insects-of-guam-test/b172
# dragonflies-of-guam directory already exists.
# thrips-of-guam directory already exists.
# cercopidae-of-guam directory already exists.
# membracidae-of-guam directory already exists.
# psyllidae-from-guam directory already exists.
# aphidae-and-aleurodidae-of-guam directory already exists.
# neuropteroid-insects-from-guam directory already exists.
# butterflies-of-guam directory already exists.
# sphingidae-of-guam directory already exists.
# staphylinidae-of-guam directory already exists.
# rhipiceridae-of-guam directory already exists.
# ciidae-of-guam directory already exists.
# elaterid-and-eucnemid-beetles-of-guam directory already exists.
# coleoptera-heteromera-from-guam directory already exists.
# new-longicorn-beetles-from-guam-cerambycidae directory already exists.
# anthribidae-of-guam directory already exists.
# curculionidae-of-guam directory already exists.
# barkbeetles-of-guam directory already exists.
# miscellaneous-families-of-guam-coleoptera directory already exists.
# stylopidae-of-guam directory already exists.
# formicidae-of-guam directory already exists.
# wasps-of-guam directory already exists.
# bees-of-guam directory already exists.
# halictine-bees-from-rota-island directory already exists.
# tipulidae-of-guam directory already exists.
# culicidae-of-guam directory already exists.
# trypetidae-otitidae-helomyzidae-and-clusiidae-of-guam-diptera directory already exists.
# /home/aubrey/insects-of-guam-test

# %% [markdown]
# At this point the directory structure should look something like this:
#
#     b172
#         anthribidae-of-guam
#             anthribidae-of-guam.pdf
#             anthribidae-of-guam-0.jpg
#             anthribidae-of-guam-1.jpg
#             ...
#         formicidae-of-guam
#             formicidae-of-guam.pdf
#             formicidae-of-guam-0.jpg
#             formicidae-of-guam-1.jpg
#             ...
#
# The PDF contains the whole section.
# There is JPG file for each page in the section.
#
# The next step is to use CVAT to record coordinates of bounding boxes which determine the position of species
# sections in the JPGs.  The resulting XML file can be downloaded into the section directory.
#
# Then, rerun this notebook, commit changes to the git repo, and push to github.

# %%
import pandas as pd
import os
import cv2

f = '{}/{}.csv'.format(bulletin, bulletin)
df = pd.read_csv(f)
for section in df.slug.values:
    print(section)
    bb_xml_path = '{}/{}/{}.xml'.format(bulletin, section, section)
    bb_xml_path_exists = os.path.exists(bb_xml_path)
    print('bb_xml_path_exists: {}'.format(bb_xml_path_exists))
    bb_csv_path = '{}/{}/bounding_boxes.csv'.format(bulletin, section)
    bb_csv_path_exists = os.path.exists(bb_csv_path)
    print('bb_csv_path_exists: {}'.format(bb_csv_path_exists))
    
    if bb_xml_path_exists and not bb_csv_path_exists:
        print('Making bb table for {}'.format(section))
        make_bounding_box_table(bulletin, section)
        
        print('Extracting bounding box images.')
        extract_bounding_box_images(bulletin, section)
        
        print('Merging bounding box images.')
        merge_bounding_box_images(bulletin, section)
        
        print('Making mturk data csv.')
        make_mturk_data_csv(bulletin, section)
    print()
# Out:
# dragonflies-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# thrips-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# cercopidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# membracidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# psyllidae-from-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# aphidae-and-aleurodidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# neuropteroid-insects-from-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# butterflies-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# sphingidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# staphylinidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# rhipiceridae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# ciidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# elaterid-and-eucnemid-beetles-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# coleoptera-heteromera-from-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# new-longicorn-beetles-from-guam-cerambycidae
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# anthribidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# curculionidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# barkbeetles-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# miscellaneous-families-of-guam-coleoptera
# bb_xml_path_exists: True
# bb_csv_path_exists: False
# Making bb table for miscellaneous-families-of-guam-coleoptera
# Extracting bounding box images.
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Chalaenius-flaviguttatus-guttatus-0.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Colpodes-1.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Colpodes-2.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Endynomena-pradieri-3.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Tachys-4.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Lesticus-5.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Eretes-sticticus-6.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Cybister-tripunctatus-hamatus-7.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Rhantus-pulverosus-8.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Sticholotis-punctatus-9.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Azya-luteipes-Mulsant-10.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Rhantus-pulverosus-11.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Rodolia-cardinalis-12.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Telsimia-nitida-13.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Lindorus-lophanthae-14.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Telsimia-nitida-15.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Nephus-16.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Pullus-17.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Stethorus-18.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Apsectus-19.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Xylothrips-religiosus-20.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Dactylosternum-abdominale-21.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Enochrus-rubrocinctus-22.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Noteropagus-obscurus-23.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Xylopsocus-capucinus-24.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Xylopsocus-capucinus-25.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Dinoderus-minutus-26.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Lasioderma-serricorne-27.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Necrobia-rufipes-28.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Tillus-notatus-29.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Buprestis-aurulenta-30.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Cyphogastra-auripennis-31.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Chrysodema-ventralis-32.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Chrysobothris-costata-33.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Agrilus-occipitalis--34.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Bradymerus-acuticostis-35.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Buprestis-aurulenta-36.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Gonocephalum-seriatum-37.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Alphitobius-laevitgatus-38.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Eutochia-lateralis-39.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Derosphaerus-rotundicollis-40.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Eutochia-lateralis-41.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Uloma-rufilabris--42.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Uloma-picicornis-43.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Tribolium-ferrugineum-44.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Scotochares-insularis-45.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Palorus-ratzeburgi-46.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Figulus-lilliputanus-47.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Xyloborus-nudus-48.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Sessinia-livida-49.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Figulus-integricollis-50.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Ataenius-gracilis-51.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Anomala-sulcatula-52.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Ataenius-gracilis-53.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Ataenius-cognatus-54.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Aphodius-lividus-55.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Holotrichia-mindanaona-56.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Ceresium-unicolor-57.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Dihammus-marianarum-58.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Holotrichia-mindanaona-59.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Espeson-crenicollis-60.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Phloeonomus-hebridensis-61.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Phloenomus-singularis-62.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Ceresium-unicolor-63.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Bidessus-gentilis-64.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Lispinus-foveatus-65.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Phloenomus-singularis-66.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Gelonaetha-hirta-67.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Prosoplus-bankii-68.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Chlorophorus-annularis-69.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Prosoplus-marianarum-70.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Aphthona-bicolorata-71.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Phloenomus-marianarum-72.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Phytorus-lineolatus-73.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Dibelonetes-formosae-74.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Stilicopsis-setigera-75.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Leptacinus-flavipennis-76.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Philonthus-discoideus-77.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Philonthus-quisquiliarius-78.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Oligota-flavicornis-79.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Trogophloeus-exiguus-80.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Astenus-horni-81.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Thamiaraea-insigniventris-82.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Oligota-flavicornis-83.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Gyrophaena-moluccensis-84.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Gyrophaena-variolosa-85.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Homalota-cribrum-86.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Tenebroides-mauritanicus-87.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Melambia-cordicollis-88.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Haptoncus-luteolus-89.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Haptoncus-ocularis-90.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Carpophilus-91.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Urophorus-humeralis--92.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Psammoecus-insularis--93.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Oryzaephilus-surinamensis-94.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Inopeplus-metallescens--95.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Haptoncus-ocularis-96.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Haptoncus--97.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Cryptamorpha-desjardinsi-98.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Neotrichus-latiusculus-99.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Inopeplus-metallescens--100.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Metophthalmus-albofasciatus-101.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Colobicus-parilis-102.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Bitoma-siccana-103.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Ocholissa-humeralis--104.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Harminia-arcuata-105.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Trochoideus-desjardinsii-106.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Anisolemnia-mulsanti-107.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Cryptolaemus-montrouzieri-108.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Coelophora-inaequalis-109.jpg
# b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Coccinella-transversalis-110.jpg
# Merging bounding box images.
# species_names:                          species_name
# 0                Agrilus occipitalis
# 1             Alphitobius laevitgatus
# 2                Anisolemnia mulsanti
# 3                   Anomala sulcatula
# 4                    Aphodius lividus
# 5                 Aphthona bicolorata
# 6                            Apsectus
# 7                       Astenus horni
# 8                   Ataenius cognatus
# 9                   Ataenius gracilis
# 10              Azya luteipes Mulsant
# 11                  Bidessus gentilis
# 12                     Bitoma siccana
# 13             Bradymerus acuticostis
# 14                Buprestis aurulenta
# 15                        Carpophilus
# 16                  Ceresium unicolor
# 17  Chalaenius flaviguttatus guttatus
# 18             Chlorophorus annularis
# 19              Chrysobothris costata
# 20               Chrysodema ventralis
# 21           Coccinella transversalis
# 22              Coelophora inaequalis
# 23                  Colobicus parilis
# 24                           Colpodes
# 25           Cryptamorpha desjardinsi
# 26          Cryptolaemus montrouzieri
# 27      Cybister tripunctatus hamatus
# 28             Cyphogastra auripennis
# 29          Dactylosternum abdominale
# ..                                ...
# 68          Philonthus quisquiliarius
# 69              Phloenomus marianarum
# 70              Phloenomus singularis
# 71            Phloeonomus hebridensis
# 72                Phytorus lineolatus
# 73                   Prosoplus bankii
# 74               Prosoplus marianarum
# 75              Psammoecus insularis
# 76                             Pullus
# 77                 Rhantus pulverosus
# 78                 Rodolia cardinalis
# 79              Scotochares insularis
# 80                    Sessinia livida
# 81                          Stethorus
# 82              Sticholotis punctatus
# 83               Stilicopsis setigera
# 84                             Tachys
# 85                    Telsimia nitida
# 86           Tenebroides mauritanicus
# 87          Thamiaraea insigniventris
# 88                     Tillus notatus
# 89              Tribolium ferrugineum
# 90           Trochoideus desjardinsii
# 91               Trogophloeus exiguus
# 92                   Uloma picicornis
# 93                  Uloma rufilabris
# 94               Urophorus humeralis
# 95                    Xyloborus nudus
# 96               Xylopsocus capucinus
# 97              Xylothrips religiosus
#
# [98 rows x 1 columns]
# Agrilus occipitalis
#                       bb_image
# 0  Agrilus-occipitalis--34.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Agrilus-occipitalis--34.jpg
# Alphitobius laevitgatus
#                          bb_image
# 0  Alphitobius-laevitgatus-38.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Alphitobius-laevitgatus-38.jpg
# Anisolemnia mulsanti
#                        bb_image
# 0  Anisolemnia-mulsanti-107.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Anisolemnia-mulsanti-107.jpg
# Anomala sulcatula
#                    bb_image
# 0  Anomala-sulcatula-52.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Anomala-sulcatula-52.jpg
# Aphodius lividus
#                   bb_image
# 0  Aphodius-lividus-55.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Aphodius-lividus-55.jpg
# Aphthona bicolorata
#                      bb_image
# 0  Aphthona-bicolorata-71.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Aphthona-bicolorata-71.jpg
# Apsectus
#           bb_image
# 0  Apsectus-19.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Apsectus-19.jpg
# Astenus horni
#                bb_image
# 0  Astenus-horni-81.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Astenus-horni-81.jpg
# Ataenius cognatus
#                    bb_image
# 0  Ataenius-cognatus-54.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Ataenius-cognatus-54.jpg
# Ataenius gracilis
#                    bb_image
# 0  Ataenius-gracilis-51.jpg
# 1  Ataenius-gracilis-53.jpg
#
# rowcount: 2
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Ataenius-gracilis-51.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Ataenius-gracilis-53.jpg
# Azya luteipes Mulsant
#                        bb_image
# 0  Azya-luteipes-Mulsant-10.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Azya-luteipes-Mulsant-10.jpg
# Bidessus gentilis
#                    bb_image
# 0  Bidessus-gentilis-64.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Bidessus-gentilis-64.jpg
# Bitoma siccana
#                  bb_image
# 0  Bitoma-siccana-103.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Bitoma-siccana-103.jpg
# Bradymerus acuticostis
#                         bb_image
# 0  Bradymerus-acuticostis-35.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Bradymerus-acuticostis-35.jpg
# Buprestis aurulenta
#                      bb_image
# 0  Buprestis-aurulenta-30.jpg
# 1  Buprestis-aurulenta-36.jpg
#
# rowcount: 2
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Buprestis-aurulenta-30.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Buprestis-aurulenta-36.jpg
# Carpophilus
#              bb_image
# 0  Carpophilus-91.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Carpophilus-91.jpg
# Ceresium unicolor
#                    bb_image
# 0  Ceresium-unicolor-57.jpg
# 1  Ceresium-unicolor-63.jpg
#
# rowcount: 2
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Ceresium-unicolor-57.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Ceresium-unicolor-63.jpg
# Chalaenius flaviguttatus guttatus
#                                   bb_image
# 0  Chalaenius-flaviguttatus-guttatus-0.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Chalaenius-flaviguttatus-guttatus-0.jpg
# Chlorophorus annularis
#                         bb_image
# 0  Chlorophorus-annularis-69.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Chlorophorus-annularis-69.jpg
# Chrysobothris costata
#                        bb_image
# 0  Chrysobothris-costata-33.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Chrysobothris-costata-33.jpg
# Chrysodema ventralis
#                       bb_image
# 0  Chrysodema-ventralis-32.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Chrysodema-ventralis-32.jpg
# Coccinella transversalis
#                            bb_image
# 0  Coccinella-transversalis-110.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Coccinella-transversalis-110.jpg
# Coelophora inaequalis
#                         bb_image
# 0  Coelophora-inaequalis-109.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Coelophora-inaequalis-109.jpg
# Colobicus parilis
#                     bb_image
# 0  Colobicus-parilis-102.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Colobicus-parilis-102.jpg
# Colpodes
#          bb_image
# 0  Colpodes-1.jpg
# 1  Colpodes-2.jpg
#
# rowcount: 2
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Colpodes-1.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Colpodes-2.jpg
# Cryptamorpha desjardinsi
#                           bb_image
# 0  Cryptamorpha-desjardinsi-98.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Cryptamorpha-desjardinsi-98.jpg
# Cryptolaemus montrouzieri
#                             bb_image
# 0  Cryptolaemus-montrouzieri-108.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Cryptolaemus-montrouzieri-108.jpg
# Cybister tripunctatus hamatus
#                               bb_image
# 0  Cybister-tripunctatus-hamatus-7.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Cybister-tripunctatus-hamatus-7.jpg
# Cyphogastra auripennis
#                         bb_image
# 0  Cyphogastra-auripennis-31.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Cyphogastra-auripennis-31.jpg
# Dactylosternum abdominale
#                            bb_image
# 0  Dactylosternum-abdominale-21.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Dactylosternum-abdominale-21.jpg
# Derosphaerus rotundicollis
#                             bb_image
# 0  Derosphaerus-rotundicollis-40.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Derosphaerus-rotundicollis-40.jpg
# Dibelonetes formosae
#                       bb_image
# 0  Dibelonetes-formosae-74.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Dibelonetes-formosae-74.jpg
# Dihammus marianarum
#                      bb_image
# 0  Dihammus-marianarum-58.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Dihammus-marianarum-58.jpg
# Dinoderus minutus
#                    bb_image
# 0  Dinoderus-minutus-26.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Dinoderus-minutus-26.jpg
# Endynomena pradieri
#                     bb_image
# 0  Endynomena-pradieri-3.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Endynomena-pradieri-3.jpg
# Enochrus rubrocinctus
#                        bb_image
# 0  Enochrus-rubrocinctus-22.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Enochrus-rubrocinctus-22.jpg
# Eretes sticticus
#                  bb_image
# 0  Eretes-sticticus-6.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Eretes-sticticus-6.jpg
# Espeson crenicollis
#                      bb_image
# 0  Espeson-crenicollis-60.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Espeson-crenicollis-60.jpg
# Eutochia lateralis
#                     bb_image
# 0  Eutochia-lateralis-39.jpg
# 1  Eutochia-lateralis-41.jpg
#
# rowcount: 2
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Eutochia-lateralis-39.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Eutochia-lateralis-41.jpg
# Figulus integricollis
#                        bb_image
# 0  Figulus-integricollis-50.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Figulus-integricollis-50.jpg
# Figulus lilliputanus
#                       bb_image
# 0  Figulus-lilliputanus-47.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Figulus-lilliputanus-47.jpg
# Gelonaetha hirta
#                   bb_image
# 0  Gelonaetha-hirta-67.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Gelonaetha-hirta-67.jpg
# Gonocephalum seriatum
#                        bb_image
# 0  Gonocephalum-seriatum-37.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Gonocephalum-seriatum-37.jpg
# Gyrophaena moluccensis
#                         bb_image
# 0  Gyrophaena-moluccensis-84.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Gyrophaena-moluccensis-84.jpg
# Gyrophaena variolosa
#                       bb_image
# 0  Gyrophaena-variolosa-85.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Gyrophaena-variolosa-85.jpg
# Haptoncus
#             bb_image
# 0  Haptoncus--97.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Haptoncus--97.jpg
# Haptoncus luteolus
#                     bb_image
# 0  Haptoncus-luteolus-89.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Haptoncus-luteolus-89.jpg
# Haptoncus ocularis
#                     bb_image
# 0  Haptoncus-ocularis-90.jpg
# 1  Haptoncus-ocularis-96.jpg
#
# rowcount: 2
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Haptoncus-ocularis-90.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Haptoncus-ocularis-96.jpg
# Harminia arcuata
#                    bb_image
# 0  Harminia-arcuata-105.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Harminia-arcuata-105.jpg
# Holotrichia mindanaona
#                         bb_image
# 0  Holotrichia-mindanaona-56.jpg
# 1  Holotrichia-mindanaona-59.jpg
#
# rowcount: 2
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Holotrichia-mindanaona-56.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Holotrichia-mindanaona-59.jpg
# Homalota cribrum
#                   bb_image
# 0  Homalota-cribrum-86.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Homalota-cribrum-86.jpg
# Inopeplus metallescens
#                           bb_image
# 0  Inopeplus-metallescens--100.jpg
# 1   Inopeplus-metallescens--95.jpg
#
# rowcount: 2
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Inopeplus-metallescens--100.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Inopeplus-metallescens--95.jpg
# Lasioderma serricorne
#                        bb_image
# 0  Lasioderma-serricorne-27.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Lasioderma-serricorne-27.jpg
# Leptacinus flavipennis
#                         bb_image
# 0  Leptacinus-flavipennis-76.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Leptacinus-flavipennis-76.jpg
# Lesticus
#          bb_image
# 0  Lesticus-5.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Lesticus-5.jpg
# Lindorus lophanthae
#                      bb_image
# 0  Lindorus-lophanthae-14.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Lindorus-lophanthae-14.jpg
# Lispinus foveatus
#                    bb_image
# 0  Lispinus-foveatus-65.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Lispinus-foveatus-65.jpg
# Melambia cordicollis
#                       bb_image
# 0  Melambia-cordicollis-88.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Melambia-cordicollis-88.jpg
# Metophthalmus albofasciatus
#                               bb_image
# 0  Metophthalmus-albofasciatus-101.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Metophthalmus-albofasciatus-101.jpg
# Necrobia rufipes
#                   bb_image
# 0  Necrobia-rufipes-28.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Necrobia-rufipes-28.jpg
# Neotrichus latiusculus
#                         bb_image
# 0  Neotrichus-latiusculus-99.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Neotrichus-latiusculus-99.jpg
# Nephus
#         bb_image
# 0  Nephus-16.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Nephus-16.jpg
# Noteropagus obscurus
#                       bb_image
# 0  Noteropagus-obscurus-23.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Noteropagus-obscurus-23.jpg
# Ocholissa humeralis
#                        bb_image
# 0  Ocholissa-humeralis--104.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Ocholissa-humeralis--104.jpg
# Oligota flavicornis
#                      bb_image
# 0  Oligota-flavicornis-79.jpg
# 1  Oligota-flavicornis-83.jpg
#
# rowcount: 2
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Oligota-flavicornis-79.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Oligota-flavicornis-83.jpg
# Oryzaephilus surinamensis
#                            bb_image
# 0  Oryzaephilus-surinamensis-94.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Oryzaephilus-surinamensis-94.jpg
# Palorus ratzeburgi
#                     bb_image
# 0  Palorus-ratzeburgi-46.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Palorus-ratzeburgi-46.jpg
# Philonthus discoideus
#                        bb_image
# 0  Philonthus-discoideus-77.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Philonthus-discoideus-77.jpg
# Philonthus quisquiliarius
#                            bb_image
# 0  Philonthus-quisquiliarius-78.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Philonthus-quisquiliarius-78.jpg
# Phloenomus marianarum
#                        bb_image
# 0  Phloenomus-marianarum-72.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Phloenomus-marianarum-72.jpg
# Phloenomus singularis
#                        bb_image
# 0  Phloenomus-singularis-62.jpg
# 1  Phloenomus-singularis-66.jpg
#
# rowcount: 2
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Phloenomus-singularis-62.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Phloenomus-singularis-66.jpg
# Phloeonomus hebridensis
#                          bb_image
# 0  Phloeonomus-hebridensis-61.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Phloeonomus-hebridensis-61.jpg
# Phytorus lineolatus
#                      bb_image
# 0  Phytorus-lineolatus-73.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Phytorus-lineolatus-73.jpg
# Prosoplus bankii
#                   bb_image
# 0  Prosoplus-bankii-68.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Prosoplus-bankii-68.jpg
# Prosoplus marianarum
#                       bb_image
# 0  Prosoplus-marianarum-70.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Prosoplus-marianarum-70.jpg
# Psammoecus insularis
#                        bb_image
# 0  Psammoecus-insularis--93.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Psammoecus-insularis--93.jpg
# Pullus
#         bb_image
# 0  Pullus-17.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Pullus-17.jpg
# Rhantus pulverosus
#                     bb_image
# 0  Rhantus-pulverosus-11.jpg
# 1   Rhantus-pulverosus-8.jpg
#
# rowcount: 2
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Rhantus-pulverosus-11.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Rhantus-pulverosus-8.jpg
# Rodolia cardinalis
#                     bb_image
# 0  Rodolia-cardinalis-12.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Rodolia-cardinalis-12.jpg
# Scotochares insularis
#                        bb_image
# 0  Scotochares-insularis-45.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Scotochares-insularis-45.jpg
# Sessinia livida
#                  bb_image
# 0  Sessinia-livida-49.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Sessinia-livida-49.jpg
# Stethorus
#            bb_image
# 0  Stethorus-18.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Stethorus-18.jpg
# Sticholotis punctatus
#                       bb_image
# 0  Sticholotis-punctatus-9.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Sticholotis-punctatus-9.jpg
# Stilicopsis setigera
#                       bb_image
# 0  Stilicopsis-setigera-75.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Stilicopsis-setigera-75.jpg
# Tachys
#        bb_image
# 0  Tachys-4.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Tachys-4.jpg
# Telsimia nitida
#                  bb_image
# 0  Telsimia-nitida-13.jpg
# 1  Telsimia-nitida-15.jpg
#
# rowcount: 2
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Telsimia-nitida-13.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Telsimia-nitida-15.jpg
# Tenebroides mauritanicus
#                           bb_image
# 0  Tenebroides-mauritanicus-87.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Tenebroides-mauritanicus-87.jpg
# Thamiaraea insigniventris
#                            bb_image
# 0  Thamiaraea-insigniventris-82.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Thamiaraea-insigniventris-82.jpg
# Tillus notatus
#                 bb_image
# 0  Tillus-notatus-29.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Tillus-notatus-29.jpg
# Tribolium ferrugineum
#                        bb_image
# 0  Tribolium-ferrugineum-44.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Tribolium-ferrugineum-44.jpg
# Trochoideus desjardinsii
#                            bb_image
# 0  Trochoideus-desjardinsii-106.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Trochoideus-desjardinsii-106.jpg
# Trogophloeus exiguus
#                       bb_image
# 0  Trogophloeus-exiguus-80.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Trogophloeus-exiguus-80.jpg
# Uloma picicornis
#                   bb_image
# 0  Uloma-picicornis-43.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Uloma-picicornis-43.jpg
# Uloma rufilabris
#                    bb_image
# 0  Uloma-rufilabris--42.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Uloma-rufilabris--42.jpg
# Urophorus humeralis
#                       bb_image
# 0  Urophorus-humeralis--92.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Urophorus-humeralis--92.jpg
# Xyloborus nudus
#                  bb_image
# 0  Xyloborus-nudus-48.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Xyloborus-nudus-48.jpg
# Xylopsocus capucinus
#                       bb_image
# 0  Xylopsocus-capucinus-24.jpg
# 1  Xylopsocus-capucinus-25.jpg
#
# rowcount: 2
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Xylopsocus-capucinus-24.jpg
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Xylopsocus-capucinus-25.jpg
# Xylothrips religiosus
#                        bb_image
# 0  Xylothrips-religiosus-20.jpg
#
# rowcount: 1
# f: b172/miscellaneous-families-of-guam-coleoptera/bounding_box_images/Xylothrips-religiosus-20.jpg
# Making mturk data csv.
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Colobicus parilis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Cyphogastra auripennis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Figulus integricollis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Dibelonetes formosae.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Cybister tripunctatus hamatus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Prosoplus marianarum.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Tachys.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Xyloborus nudus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Derosphaerus rotundicollis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Trochoideus desjardinsii.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Apsectus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Xylothrips religiosus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Harminia arcuata.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Phloeonomus hebridensis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Bidessus gentilis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Bitoma siccana.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Inopeplus metallescens .jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Tillus notatus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Phytorus lineolatus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Cryptamorpha desjardinsi.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Philonthus discoideus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Endynomena pradieri.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Uloma rufilabris .jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Colpodes.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Aphodius lividus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Gyrophaena moluccensis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Chrysodema ventralis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Trogophloeus exiguus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Necrobia rufipes.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Dactylosternum abdominale.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Ataenius gracilis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Haptoncus ocularis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Pullus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Gelonaetha hirta.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Agrilus occipitalis .jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Sessinia livida.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Noteropagus obscurus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Lispinus foveatus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Dinoderus minutus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Ataenius cognatus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Haptoncus luteolus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Oligota flavicornis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Chlorophorus annularis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Homalota cribrum.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Urophorus humeralis .jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Chrysobothris costata.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Figulus lilliputanus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Psammoecus insularis .jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Buprestis aurulenta.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Scotochares insularis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Telsimia nitida.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Azya luteipes Mulsant.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Lesticus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Stethorus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Phloenomus singularis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Alphitobius laevitgatus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Bradymerus acuticostis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Dihammus marianarum.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Stilicopsis setigera.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Ceresium unicolor.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Eutochia lateralis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Gyrophaena variolosa.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Enochrus rubrocinctus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Melambia cordicollis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Coelophora inaequalis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Tenebroides mauritanicus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Uloma picicornis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Prosoplus bankii.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Anisolemnia mulsanti.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Xylopsocus capucinus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Rhantus pulverosus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Carpophilus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Holotrichia mindanaona.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Haptoncus .jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Tribolium ferrugineum.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Lindorus lophanthae.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Palorus ratzeburgi.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Anomala sulcatula.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Sticholotis punctatus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Eretes sticticus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Nephus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Neotrichus latiusculus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Lasioderma serricorne.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Astenus horni.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Rodolia cardinalis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Gonocephalum seriatum.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Cryptolaemus montrouzieri.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Philonthus quisquiliarius.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Metophthalmus albofasciatus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Aphthona bicolorata.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Phloenomus marianarum.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Coccinella transversalis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Leptacinus flavipennis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Thamiaraea insigniventris.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Chalaenius flaviguttatus guttatus.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Oryzaephilus surinamensis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Espeson crenicollis.jpg
# performing optical character recognition on b172/miscellaneous-families-of-guam-coleoptera/merged_images/Ocholissa humeralis .jpg
#
# stylopidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# formicidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# wasps-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# bees-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# halictine-bees-from-rota-island
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# tipulidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# culicidae-of-guam
# bb_xml_path_exists: True
# bb_csv_path_exists: True
#
# trypetidae-otitidae-helomyzidae-and-clusiidae-of-guam-diptera
# bb_xml_path_exists: True
# bb_csv_path_exists: True

# %% [markdown]
# # END
